# %%
import sys
sys.path.insert(0, './ml')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, plot_roc_curve
from sklearn.preprocessing import StandardScaler

from ml.gs_rf import grid_search
from ml.SVM_RF import run as run_model
from ml import ML_util

from features.spatial_features_calc import get_spatial_features_names
from features.morphological_features_calc import get_morphological_features_names
from features.temporal_features_calc import get_temporal_features_names

# %%
chunks = [0, 500, 200]
modalities = ['spatial', 'morphological', 'temporal', 'spat_tempo']
restrictions = ['complete', 'no_small_sample']

n_estimators_min = 0
n_estimators_max = 2
n_estimators_num = 3
max_depth_min = 1
max_depth_max = 2
max_depth_num = 2
min_samples_splits_min = 1
min_samples_splits_max = 5
min_samples_splits_num = 5
min_samples_leafs_min = 0
min_samples_leafs_max = 5
min_samples_leafs_num = 6
n = 10

# %%
def calc_auc(clf, data_path):
    train, dev, test, _, _, _ = ML_util.get_dataset(data_path)
    train = np.concatenate((train, dev))
    train_squeezed = ML_util.squeeze_clusters(train)
    train_features, train_labels = ML_util.split_features(train_squeezed)
    
    scaler = StandardScaler()
    scaler.fit(train_features)
    train_features = scaler.transform(train_features)
    
    preds = []
    targets = []
    
    for cluster in test:
        features, labels = ML_util.split_features(cluster)
        features = np.nan_to_num(features)
        features = scaler.transform(features)
        label = labels[0]  # as they are the same for all the cluster
        pred = clf.predict_proba(features).mean(axis=0)[1]
        preds.append(pred)
        targets.append(label)
    
    fpr, tpr, thresholds = roc_curve(targets, preds)  # calculate fpr and tpr values for different thresholds
    auc_val = auc(fpr, tpr)
        
    return auc_val

def get_modality_results(data_path):
    accs, pyr_accs, in_accs, aucs = [], [], [], []
    
    clf, acc, pyr_acc, in_acc, n_estimators, max_depth, min_samples_split, min_samples_leaf = grid_search(
        data_path + "/0_0.60.20.2/", False, n_estimators_min, n_estimators_max, n_estimators_num,
        max_depth_min, max_depth_max, max_depth_num, min_samples_splits_min, min_samples_splits_max,
        min_samples_splits_num, min_samples_leafs_min, min_samples_leafs_max, min_samples_leafs_num, n)
    auc = calc_auc(clf, data_path + "/0_0.60.20.2/")
    
    accs.append(acc)
    pyr_accs.append(pyr_acc)
    in_accs.append(in_acc)
    aucs.append(auc)
    
    restriction, modality = data_path.split('/')[-2:]
    
    if modality == 'temporal':
        accs = accs * len(chunks)
        pyr_accs = pyr_accs * len(chunks)
        in_accs = in_accs * len(chunks)
        aucs = aucs * len(chunks)
    else:
        for chunk_size in chunks[1:]:
            clf, acc, pyr_acc, in_acc = run_model('rf', None, None, None, False, None, False, True, False, None, None, None,
                n_estimators, max_depth, min_samples_split, min_samples_leaf, data_path + f"/{chunk_size}_0.60.20.2/")
            auc = calc_auc(clf, data_path + f"/{chunk_size}_0.60.20.2/")
            
            accs.append(acc)
            pyr_accs.append(pyr_acc)
            in_accs.append(in_acc)
            aucs.append(auc)
        
    df = pd.DataFrame({'restriction': restriction, 'modality': modality, 'chunk_size': chunks,
                           'acc': accs, 'pyr_acc': pyr_accs, 'in_acc': in_accs, 'auc': aucs})
    
    return df
                                       
def get_folder_results(data_path):
    df = pd.DataFrame({'restriction': [], 'modality': [], 'chunk_size': [], 'acc': [], 'pyr_acc': [], 'in_acc': [], 'auc': []})
    for modality in modalities:
        modaility_df = get_modality_results(data_path + '/' + modality)
        df = df.append(modaility_df, ignore_index=True)
        
    return df

def get_results(data_path):
    df = pd.DataFrame({'restriction': [], 'modality': [], 'chunk_size': [], 'acc': [], 'pyr_acc': [], 'in_acc': [], 'auc': []})
    for restriction in restrictions:
        folder_df = get_folder_results(data_path + '/' + restriction)
        df = df.append(folder_df, ignore_index=True)
        
    return df

# %%
results = get_results('./data_sets')
# Out:
# Loading data set from ./data_sets/complete/spatial/0_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 306 waveforms (59.766%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 246 waveforms (80.392%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 60 waveforms (19.608%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 102 waveforms (19.922%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 82 waveforms (80.392%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 20 waveforms (19.608%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 104 waveforms (20.312%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 83 waveforms (79.808%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 21 waveforms (20.192%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
#
# Starting grid search...
# Grid search completed in 73.47 seconds, best parameters are:
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# Grid search completed in 73.47 seconds, best parameters are:
#
# Starting evaluation on test set...
# Loading data set from ./data_sets/complete/spatial/0_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 306 waveforms (59.766%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 246 waveforms (80.392%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 60 waveforms (19.608%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 102 waveforms (19.922%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 82 waveforms (80.392%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 20 waveforms (19.608%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 104 waveforms (20.312%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 83 waveforms (79.808%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 21 waveforms (20.192%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Chosen model is Random Forest
# Loading data set from ./data_sets/complete/spatial/500_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 28411 waveforms (61.742%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 7949 waveforms (27.979%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 20462 waveforms (72.021%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 6559 waveforms (14.254%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 2668 waveforms (40.677%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 3891 waveforms (59.323%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 11046 waveforms (24.005%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 2923 waveforms (26.462%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 8123 waveforms (73.538%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Scaling data...
# Fitting Random Forest model...
# Fitting took 3.21 seconds
# Evaluating predictions...
# Number of correct classified clusters is 85, which is 81.7308%
# Number of correct classified chunks is 6271, which is 56.7717%
# Test set consists of 83 pyramidal cells and 21 interneurons
# 87.9518% of pyramidal cells classified correctly
# 57.1429% of interneurons classified correctly
# Loading data set from ./data_sets/complete/spatial/500_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 28411 waveforms (61.742%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 7949 waveforms (27.979%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 20462 waveforms (72.021%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 6559 waveforms (14.254%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 2668 waveforms (40.677%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 3891 waveforms (59.323%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 11046 waveforms (24.005%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 2923 waveforms (26.462%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 8123 waveforms (73.538%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Chosen model is Random Forest
# Loading data set from ./data_sets/complete/spatial/200_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 71270 waveforms (61.740%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 20067 waveforms (28.156%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 51203 waveforms (71.844%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 16465 waveforms (14.263%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 6725 waveforms (40.844%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 9740 waveforms (59.156%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 27701 waveforms (23.997%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 7379 waveforms (26.638%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 20322 waveforms (73.362%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Scaling data...
# Fitting Random Forest model...
# Fitting took 9.27 seconds
# Evaluating predictions...
# Number of correct classified clusters is 90, which is 86.5385%
# Number of correct classified chunks is 19164, which is 69.1816%
# Test set consists of 83 pyramidal cells and 21 interneurons
# 87.9518% of pyramidal cells classified correctly
# 80.9524% of interneurons classified correctly
# Loading data set from ./data_sets/complete/spatial/200_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 71270 waveforms (61.740%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 20067 waveforms (28.156%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 51203 waveforms (71.844%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 16465 waveforms (14.263%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 6725 waveforms (40.844%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 9740 waveforms (59.156%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 27701 waveforms (23.997%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 7379 waveforms (26.638%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 20322 waveforms (73.362%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Loading data set from ./data_sets/complete/morphological/0_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 306 waveforms (59.766%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 246 waveforms (80.392%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 60 waveforms (19.608%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 102 waveforms (19.922%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 82 waveforms (80.392%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 20 waveforms (19.608%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 104 waveforms (20.312%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 83 waveforms (79.808%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 21 waveforms (20.192%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
#
# Starting grid search...
# Grid search completed in 66.52 seconds, best parameters are:
# {'max_depth': 10, 'min_samples_leaf': 8, 'min_samples_split': 32, 'n_estimators': 100}
# Grid search completed in 66.52 seconds, best parameters are:
#
# Starting evaluation on test set...
# Loading data set from ./data_sets/complete/morphological/0_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 306 waveforms (59.766%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 246 waveforms (80.392%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 60 waveforms (19.608%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 102 waveforms (19.922%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 82 waveforms (80.392%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 20 waveforms (19.608%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 104 waveforms (20.312%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 83 waveforms (79.808%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 21 waveforms (20.192%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Chosen model is Random Forest
# Loading data set from ./data_sets/complete/morphological/500_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 28411 waveforms (61.742%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 7949 waveforms (27.979%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 20462 waveforms (72.021%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 6559 waveforms (14.254%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 2668 waveforms (40.677%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 3891 waveforms (59.323%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 11046 waveforms (24.005%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 2923 waveforms (26.462%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 8123 waveforms (73.538%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Scaling data...
# Fitting Random Forest model...
# Fitting took 1.74 seconds
# Evaluating predictions...
# Number of correct classified clusters is 103, which is 99.0385%
# Number of correct classified chunks is 10593, which is 95.8990%
# Test set consists of 83 pyramidal cells and 21 interneurons
# 100.0000% of pyramidal cells classified correctly
# 95.2381% of interneurons classified correctly
# Loading data set from ./data_sets/complete/morphological/500_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 28411 waveforms (61.742%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 7949 waveforms (27.979%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 20462 waveforms (72.021%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 6559 waveforms (14.254%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 2668 waveforms (40.677%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 3891 waveforms (59.323%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 11046 waveforms (24.005%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 2923 waveforms (26.462%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 8123 waveforms (73.538%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Chosen model is Random Forest
# Loading data set from ./data_sets/complete/morphological/200_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 71270 waveforms (61.740%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 20067 waveforms (28.156%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 51203 waveforms (71.844%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 16465 waveforms (14.263%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 6725 waveforms (40.844%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 9740 waveforms (59.156%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 27701 waveforms (23.997%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 7379 waveforms (26.638%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 20322 waveforms (73.362%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Scaling data...
# Fitting Random Forest model...
# Fitting took 5.77 seconds
# Evaluating predictions...
# Number of correct classified clusters is 103, which is 99.0385%
# Number of correct classified chunks is 26704, which is 96.4009%
# Test set consists of 83 pyramidal cells and 21 interneurons
# 100.0000% of pyramidal cells classified correctly
# 95.2381% of interneurons classified correctly
# Loading data set from ./data_sets/complete/morphological/200_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 71270 waveforms (61.740%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 20067 waveforms (28.156%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 51203 waveforms (71.844%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 16465 waveforms (14.263%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 6725 waveforms (40.844%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 9740 waveforms (59.156%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 27701 waveforms (23.997%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 7379 waveforms (26.638%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 20322 waveforms (73.362%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Loading data set from ./data_sets/complete/temporal/0_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 306 waveforms (59.766%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 246 waveforms (80.392%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 60 waveforms (19.608%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 102 waveforms (19.922%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 82 waveforms (80.392%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 20 waveforms (19.608%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 104 waveforms (20.312%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 83 waveforms (79.808%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 21 waveforms (20.192%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
#
# Starting grid search...
# Grid search completed in 67.55 seconds, best parameters are:
# {'max_depth': 100, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Grid search completed in 67.55 seconds, best parameters are:
#
# Starting evaluation on test set...
# Loading data set from ./data_sets/complete/temporal/0_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 306 waveforms (59.766%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 246 waveforms (80.392%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 60 waveforms (19.608%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 102 waveforms (19.922%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 82 waveforms (80.392%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 20 waveforms (19.608%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 104 waveforms (20.312%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 83 waveforms (79.808%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 21 waveforms (20.192%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Loading data set from ./data_sets/complete/spat_tempo/0_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 306 waveforms (59.766%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 246 waveforms (80.392%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 60 waveforms (19.608%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 102 waveforms (19.922%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 82 waveforms (80.392%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 20 waveforms (19.608%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 104 waveforms (20.312%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 83 waveforms (79.808%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 21 waveforms (20.192%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
#
# Starting grid search...
# Grid search completed in 73.62 seconds, best parameters are:
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Grid search completed in 73.62 seconds, best parameters are:
#
# Starting evaluation on test set...
# Loading data set from ./data_sets/complete/spat_tempo/0_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 306 waveforms (59.766%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 246 waveforms (80.392%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 60 waveforms (19.608%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 102 waveforms (19.922%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 82 waveforms (80.392%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 20 waveforms (19.608%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 104 waveforms (20.312%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 83 waveforms (79.808%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 21 waveforms (20.192%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Chosen model is Random Forest
# Loading data set from ./data_sets/complete/spat_tempo/500_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 28411 waveforms (61.742%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 7949 waveforms (27.979%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 20462 waveforms (72.021%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 6559 waveforms (14.254%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 2668 waveforms (40.677%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 3891 waveforms (59.323%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 11046 waveforms (24.005%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 2923 waveforms (26.462%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 8123 waveforms (73.538%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Scaling data...
# Fitting Random Forest model...
# Fitting took 2.66 seconds
# Evaluating predictions...
# Number of correct classified clusters is 95, which is 91.3462%
# Number of correct classified chunks is 9666, which is 87.5068%
# Test set consists of 83 pyramidal cells and 21 interneurons
# 91.5663% of pyramidal cells classified correctly
# 90.4762% of interneurons classified correctly
# Loading data set from ./data_sets/complete/spat_tempo/500_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 28411 waveforms (61.742%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 7949 waveforms (27.979%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 20462 waveforms (72.021%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 6559 waveforms (14.254%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 2668 waveforms (40.677%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 3891 waveforms (59.323%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 11046 waveforms (24.005%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 2923 waveforms (26.462%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 8123 waveforms (73.538%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Chosen model is Random Forest
# Loading data set from ./data_sets/complete/spat_tempo/200_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 71270 waveforms (61.740%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 20067 waveforms (28.156%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 51203 waveforms (71.844%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 16465 waveforms (14.263%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 6725 waveforms (40.844%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 9740 waveforms (59.156%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 27701 waveforms (23.997%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 7379 waveforms (26.638%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 20322 waveforms (73.362%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Scaling data...
# Fitting Random Forest model...
# Fitting took 7.82 seconds
# Evaluating predictions...
# Number of correct classified clusters is 96, which is 92.3077%
# Number of correct classified chunks is 24339, which is 87.8633%
# Test set consists of 83 pyramidal cells and 21 interneurons
# 92.7711% of pyramidal cells classified correctly
# 90.4762% of interneurons classified correctly
# Loading data set from ./data_sets/complete/spat_tempo/200_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 71270 waveforms (61.740%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 20067 waveforms (28.156%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 51203 waveforms (71.844%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 16465 waveforms (14.263%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 6725 waveforms (40.844%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 9740 waveforms (59.156%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 27701 waveforms (23.997%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 7379 waveforms (26.638%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 20322 waveforms (73.362%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Loading data set from ./data_sets/no_small_sample/spatial/0_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 202 waveforms (59.587%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 148 waveforms (73.267%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 54 waveforms (26.733%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 68 waveforms (20.059%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 50 waveforms (73.529%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 18 waveforms (26.471%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 69 waveforms (20.354%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 50 waveforms (72.464%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 19 waveforms (27.536%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
#
# Starting grid search...
# Grid search completed in 64.34 seconds, best parameters are:
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Grid search completed in 64.34 seconds, best parameters are:
#
# Starting evaluation on test set...
# Loading data set from ./data_sets/no_small_sample/spatial/0_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 202 waveforms (59.587%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 148 waveforms (73.267%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 54 waveforms (26.733%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 68 waveforms (20.059%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 50 waveforms (73.529%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 18 waveforms (26.471%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 69 waveforms (20.354%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 50 waveforms (72.464%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 19 waveforms (27.536%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Chosen model is Random Forest
# Loading data set from ./data_sets/no_small_sample/spatial/500_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 26056 waveforms (58.595%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 6767 waveforms (25.971%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 19289 waveforms (74.029%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 9678 waveforms (21.764%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 2646 waveforms (27.340%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 7032 waveforms (72.660%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 8734 waveforms (19.641%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 2678 waveforms (30.662%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 6056 waveforms (69.338%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Scaling data...
# Fitting Random Forest model...
# Fitting took 3.22 seconds
# Evaluating predictions...
# Number of correct classified clusters is 63, which is 91.3043%
# Number of correct classified chunks is 6860, which is 78.5436%
# Test set consists of 50 pyramidal cells and 19 interneurons
# 94.0000% of pyramidal cells classified correctly
# 84.2105% of interneurons classified correctly
# Loading data set from ./data_sets/no_small_sample/spatial/500_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 26056 waveforms (58.595%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 6767 waveforms (25.971%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 19289 waveforms (74.029%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 9678 waveforms (21.764%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 2646 waveforms (27.340%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 7032 waveforms (72.660%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 8734 waveforms (19.641%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 2678 waveforms (30.662%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 6056 waveforms (69.338%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Chosen model is Random Forest
# Loading data set from ./data_sets/no_small_sample/spatial/200_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 65305 waveforms (58.598%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 17040 waveforms (26.093%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 48265 waveforms (73.907%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 24244 waveforms (21.754%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 6649 waveforms (27.425%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 17595 waveforms (72.575%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 21896 waveforms (19.647%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 6741 waveforms (30.786%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 15155 waveforms (69.214%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Scaling data...
# Fitting Random Forest model...
# Fitting took 9.13 seconds
# Evaluating predictions...
# Number of correct classified clusters is 63, which is 91.3043%
# Number of correct classified chunks is 17412, which is 79.5214%
# Test set consists of 50 pyramidal cells and 19 interneurons
# 92.0000% of pyramidal cells classified correctly
# 89.4737% of interneurons classified correctly
# Loading data set from ./data_sets/no_small_sample/spatial/200_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 65305 waveforms (58.598%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 17040 waveforms (26.093%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 48265 waveforms (73.907%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 24244 waveforms (21.754%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 6649 waveforms (27.425%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 17595 waveforms (72.575%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 21896 waveforms (19.647%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 6741 waveforms (30.786%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 15155 waveforms (69.214%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Loading data set from ./data_sets/no_small_sample/morphological/0_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 202 waveforms (59.587%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 148 waveforms (73.267%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 54 waveforms (26.733%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 68 waveforms (20.059%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 50 waveforms (73.529%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 18 waveforms (26.471%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 69 waveforms (20.354%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 50 waveforms (72.464%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 19 waveforms (27.536%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
#
# Starting grid search...
# Grid search completed in 60.57 seconds, best parameters are:
# {'max_depth': 100, 'min_samples_leaf': 4, 'min_samples_split': 16, 'n_estimators': 100}
# Grid search completed in 60.57 seconds, best parameters are:
#
# Starting evaluation on test set...
# Loading data set from ./data_sets/no_small_sample/morphological/0_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 202 waveforms (59.587%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 148 waveforms (73.267%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 54 waveforms (26.733%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 68 waveforms (20.059%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 50 waveforms (73.529%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 18 waveforms (26.471%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 69 waveforms (20.354%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 50 waveforms (72.464%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 19 waveforms (27.536%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Chosen model is Random Forest
# Loading data set from ./data_sets/no_small_sample/morphological/500_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 26056 waveforms (58.595%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 6767 waveforms (25.971%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 19289 waveforms (74.029%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 9678 waveforms (21.764%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 2646 waveforms (27.340%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 7032 waveforms (72.660%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 8734 waveforms (19.641%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 2678 waveforms (30.662%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 6056 waveforms (69.338%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Scaling data...
# Fitting Random Forest model...
# Fitting took 1.64 seconds
# Evaluating predictions...
# Number of correct classified clusters is 69, which is 100.0000%
# Number of correct classified chunks is 8734, which is 100.0000%
# Test set consists of 50 pyramidal cells and 19 interneurons
# 100.0000% of pyramidal cells classified correctly
# 100.0000% of interneurons classified correctly
# Loading data set from ./data_sets/no_small_sample/morphological/500_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 26056 waveforms (58.595%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 6767 waveforms (25.971%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 19289 waveforms (74.029%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 9678 waveforms (21.764%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 2646 waveforms (27.340%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 7032 waveforms (72.660%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 8734 waveforms (19.641%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 2678 waveforms (30.662%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 6056 waveforms (69.338%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Chosen model is Random Forest
# Loading data set from ./data_sets/no_small_sample/morphological/200_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 65305 waveforms (58.598%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 17040 waveforms (26.093%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 48265 waveforms (73.907%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 24244 waveforms (21.754%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 6649 waveforms (27.425%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 17595 waveforms (72.575%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 21896 waveforms (19.647%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 6741 waveforms (30.786%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 15155 waveforms (69.214%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Scaling data...
# Fitting Random Forest model...
# Fitting took 5.13 seconds
# Evaluating predictions...
# Number of correct classified clusters is 69, which is 100.0000%
# Number of correct classified chunks is 21891, which is 99.9772%
# Test set consists of 50 pyramidal cells and 19 interneurons
# 100.0000% of pyramidal cells classified correctly
# 100.0000% of interneurons classified correctly
# Loading data set from ./data_sets/no_small_sample/morphological/200_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 65305 waveforms (58.598%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 17040 waveforms (26.093%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 48265 waveforms (73.907%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 24244 waveforms (21.754%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 6649 waveforms (27.425%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 17595 waveforms (72.575%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 21896 waveforms (19.647%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 6741 waveforms (30.786%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 15155 waveforms (69.214%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Loading data set from ./data_sets/no_small_sample/temporal/0_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 202 waveforms (59.587%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 148 waveforms (73.267%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 54 waveforms (26.733%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 68 waveforms (20.059%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 50 waveforms (73.529%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 18 waveforms (26.471%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 69 waveforms (20.354%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 50 waveforms (72.464%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 19 waveforms (27.536%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
#
# Starting grid search...
# Grid search completed in 61.01 seconds, best parameters are:
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# Grid search completed in 61.01 seconds, best parameters are:
#
# Starting evaluation on test set...
# Loading data set from ./data_sets/no_small_sample/temporal/0_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 202 waveforms (59.587%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 148 waveforms (73.267%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 54 waveforms (26.733%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 68 waveforms (20.059%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 50 waveforms (73.529%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 18 waveforms (26.471%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 69 waveforms (20.354%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 50 waveforms (72.464%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 19 waveforms (27.536%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Loading data set from ./data_sets/no_small_sample/spat_tempo/0_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 202 waveforms (59.587%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 148 waveforms (73.267%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 54 waveforms (26.733%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 68 waveforms (20.059%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 50 waveforms (73.529%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 18 waveforms (26.471%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 69 waveforms (20.354%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 50 waveforms (72.464%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 19 waveforms (27.536%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
#
# Starting grid search...
# Grid search completed in 65.03 seconds, best parameters are:
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# Grid search completed in 65.03 seconds, best parameters are:
#
# Starting evaluation on test set...
# Loading data set from ./data_sets/no_small_sample/spat_tempo/0_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 202 waveforms (59.587%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 148 waveforms (73.267%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 54 waveforms (26.733%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 68 waveforms (20.059%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 50 waveforms (73.529%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 18 waveforms (26.471%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 69 waveforms (20.354%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 50 waveforms (72.464%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 19 waveforms (27.536%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Chosen model is Random Forest
# Loading data set from ./data_sets/no_small_sample/spat_tempo/500_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 26056 waveforms (58.595%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 6767 waveforms (25.971%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 19289 waveforms (74.029%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 9678 waveforms (21.764%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 2646 waveforms (27.340%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 7032 waveforms (72.660%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 8734 waveforms (19.641%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 2678 waveforms (30.662%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 6056 waveforms (69.338%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Scaling data...
# Fitting Random Forest model...
# Fitting took 2.63 seconds
# Evaluating predictions...
# Number of correct classified clusters is 64, which is 92.7536%
# Number of correct classified chunks is 8086, which is 92.5807%
# Test set consists of 50 pyramidal cells and 19 interneurons
# 92.0000% of pyramidal cells classified correctly
# 94.7368% of interneurons classified correctly
# Loading data set from ./data_sets/no_small_sample/spat_tempo/500_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 26056 waveforms (58.595%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 6767 waveforms (25.971%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 19289 waveforms (74.029%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 9678 waveforms (21.764%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 2646 waveforms (27.340%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 7032 waveforms (72.660%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 8734 waveforms (19.641%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 2678 waveforms (30.662%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 6056 waveforms (69.338%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Chosen model is Random Forest
# Loading data set from ./data_sets/no_small_sample/spat_tempo/200_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 65305 waveforms (58.598%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 17040 waveforms (26.093%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 48265 waveforms (73.907%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 24244 waveforms (21.754%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 6649 waveforms (27.425%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 17595 waveforms (72.575%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 21896 waveforms (19.647%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 6741 waveforms (30.786%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 15155 waveforms (69.214%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Scaling data...
# Fitting Random Forest model...
# Fitting took 7.37 seconds
# Evaluating predictions...
# Number of correct classified clusters is 64, which is 92.7536%
# Number of correct classified chunks is 20624, which is 94.1907%
# Test set consists of 50 pyramidal cells and 19 interneurons
# 96.0000% of pyramidal cells classified correctly
# 84.2105% of interneurons classified correctly
# Loading data set from ./data_sets/no_small_sample/spat_tempo/200_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 65305 waveforms (58.598%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 17040 waveforms (26.093%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 48265 waveforms (73.907%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 24244 waveforms (21.754%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 6649 waveforms (27.425%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 17595 waveforms (72.575%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 21896 waveforms (19.647%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 6741 waveforms (30.786%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 15155 waveforms (69.214%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)

# %%
print(results)
# Out:
#         restriction       modality  chunk_size         acc     pyr_acc  \
# 0          complete        spatial         0.0   86.538462   93.975904
# 1          complete        spatial       500.0   81.730769   87.951807
# 2          complete        spatial       200.0   86.538462   87.951807
# 3          complete  morphological         0.0  100.000000  100.000000
# 4          complete  morphological       500.0   99.038462  100.000000
# 5          complete  morphological       200.0   99.038462  100.000000
# 6          complete       temporal         0.0   88.461538   90.361446
# 7          complete       temporal       500.0   88.461538   90.361446
# 8          complete       temporal       200.0   88.461538   90.361446
# 9          complete     spat_tempo         0.0   92.307692   92.771084
# 10         complete     spat_tempo       500.0   91.346154   91.566265
# 11         complete     spat_tempo       200.0   92.307692   92.771084
# 12  no_small_sample        spatial         0.0   85.507246   90.000000
# 13  no_small_sample        spatial       500.0   91.304348   94.000000
# 14  no_small_sample        spatial       200.0   91.304348   92.000000
# 15  no_small_sample  morphological         0.0  100.000000  100.000000
# 16  no_small_sample  morphological       500.0  100.000000  100.000000
# 17  no_small_sample  morphological       200.0  100.000000  100.000000
# 18  no_small_sample       temporal         0.0   89.855072   90.000000
# 19  no_small_sample       temporal       500.0   89.855072   90.000000
# 20  no_small_sample       temporal       200.0   89.855072   90.000000
# 21  no_small_sample     spat_tempo         0.0   91.304348   92.000000
# 22  no_small_sample     spat_tempo       500.0   92.753623   92.000000
# 23  no_small_sample     spat_tempo       200.0   92.753623   96.000000
#
#         in_acc       auc
# 0    57.142857  0.917384
# 1    57.142857  0.902467
# 2    80.952381  0.930579
# 3   100.000000  1.000000
# 4    95.238095  1.000000
# 5    95.238095  1.000000
# 6    80.952381  0.958118
# 7    80.952381  0.958118
# 8    80.952381  0.958118
# 9    90.476190  0.966724
# 10   90.476190  0.975904
# 11   90.476190  0.973609
# 12   73.684211  0.864211
# 13   84.210526  0.900000
# 14   89.473684  0.906316
# 15  100.000000  1.000000
# 16  100.000000  1.000000
# 17  100.000000  1.000000
# 18   89.473684  0.983158
# 19   89.473684  0.983158
# 20   89.473684  0.983158
# 21   89.473684  0.974737
# 22   94.736842  0.986316
# 23   84.210526  0.989474

# %%
results = results.set_index(['restriction', 'modality', 'chunk_size'], append=True)  # create multi-index

# %%
results.to_csv('results_for_report.csv')

# %%
results
# Out:
#                                                     acc     pyr_acc  \
#    restriction     modality      chunk_size
# 0  complete        spatial       0.0          86.538462   93.975904
# 1  complete        spatial       500.0        81.730769   87.951807
# 2  complete        spatial       200.0        86.538462   87.951807
# 3  complete        morphological 0.0         100.000000  100.000000
# 4  complete        morphological 500.0        99.038462  100.000000
# 5  complete        morphological 200.0        99.038462  100.000000
# 6  complete        temporal      0.0          88.461538   90.361446
# 7  complete        temporal      500.0        88.461538   90.361446
# 8  complete        temporal      200.0        88.461538   90.361446
# 9  complete        spat_tempo    0.0          92.307692   92.771084
# 10 complete        spat_tempo    500.0        91.346154   91.566265
# 11 complete        spat_tempo    200.0        92.307692   92.771084
# 12 no_small_sample spatial       0.0          85.507246   90.000000
# 13 no_small_sample spatial       500.0        91.304348   94.000000
# 14 no_small_sample spatial       200.0        91.304348   92.000000
# 15 no_small_sample morphological 0.0         100.000000  100.000000
# 16 no_small_sample morphological 500.0       100.000000  100.000000
# 17 no_small_sample morphological 200.0       100.000000  100.000000
# 18 no_small_sample temporal      0.0          89.855072   90.000000
# 19 no_small_sample temporal      500.0        89.855072   90.000000
# 20 no_small_sample temporal      200.0        89.855072   90.000000
# 21 no_small_sample spat_tempo    0.0          91.304348   92.000000
# 22 no_small_sample spat_tempo    500.0        92.753623   92.000000
# 23 no_small_sample spat_tempo    200.0        92.753623   96.000000
#
#                                                  in_acc       auc
#    restriction     modality      chunk_size
# 0  complete        spatial       0.0          57.142857  0.917384
# 1  complete        spatial       500.0        57.142857  0.902467
# 2  complete        spatial       200.0        80.952381  0.930579
# 3  complete        morphological 0.0         100.000000  1.000000
# 4  complete        morphological 500.0        95.238095  1.000000
# 5  complete        morphological 200.0        95.238095  1.000000
# 6  complete        temporal      0.0          80.952381  0.958118
# 7  complete        temporal      500.0        80.952381  0.958118
# 8  complete        temporal      200.0        80.952381  0.958118
# 9  complete        spat_tempo    0.0          90.476190  0.966724
# 10 complete        spat_tempo    500.0        90.476190  0.975904
# 11 complete        spat_tempo    200.0        90.476190  0.973609
# 12 no_small_sample spatial       0.0          73.684211  0.864211
# 13 no_small_sample spatial       500.0        84.210526  0.900000
# 14 no_small_sample spatial       200.0        89.473684  0.906316
# 15 no_small_sample morphological 0.0         100.000000  1.000000
# 16 no_small_sample morphological 500.0       100.000000  1.000000
# 17 no_small_sample morphological 200.0       100.000000  1.000000
# 18 no_small_sample temporal      0.0          89.473684  0.983158
# 19 no_small_sample temporal      500.0        89.473684  0.983158
# 20 no_small_sample temporal      200.0        89.473684  0.983158
# 21 no_small_sample spat_tempo    0.0          89.473684  0.974737
# 22 no_small_sample spat_tempo    500.0        94.736842  0.986316
# 23 no_small_sample spat_tempo    200.0        84.210526  0.989474

# %%
def get_num_cells(restriction):
    data_path = f"./data_sets/{restriction}/spatial/0_0.60.20.2/"
    train, dev, test, _, _, _ = ML_util.get_dataset(data_path)
    tot_n = len(train) + len(dev) + len(test)
    test_n = len(test)
    pyr_n = len([cell for cell in test if cell[0][-1] == 1])
    in_n = len([cell for cell in test if cell[0][-1] == 0])
    return tot_n, test_n, pyr_n, in_n

def autolabel(rects, ax):
    """
    Attach a text label above each bar in *rects*, displaying its height.
    This function was taken from https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py
    """
    for rect in rects:
        height = rect.get_height()
        if height == 0:
            continue
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

def plot_results(df, restriction, acc=True):
    tot_n, test_n, pyr_n, in_n = get_num_cells(restriction)
    
    labels = modalities
    
    if acc:
        zero = df.xs(0, level="chunk_size").acc
        five_hundred = df.xs(500, level="chunk_size").acc
        two_hundred = df.xs(200, level="chunk_size").acc
    else:
        zero = df.xs(0, level="chunk_size").auc
        five_hundred = df.xs(500, level="chunk_size").auc
        two_hundred = df.xs(200, level="chunk_size").auc

    x = np.arange(len(labels))  # the label locations
    width = 0.3  # the width of the bars

    fig, ax = plt.subplots(figsize = (12, 12))
    rects1 = ax.bar(x - width, zero, width, label='chunk_size = 0')
    rects2 = ax.bar(x, five_hundred, width, label='chunk_size = 500')
    rects3 = ax.bar(x + width, two_hundred, width, label='chunk_size = 200')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Scores (percentage)')
    ax.set_title(f"Scores by modality and chunk size; Total={tot_n}, Test={test_n}, PYR={pyr_n}, IN={in_n}")
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend()

    autolabel(rects1, ax)
    autolabel(rects2, ax)
    autolabel(rects3, ax)

    fig.tight_layout()

    plt.show()

# %%
complete = results.loc[:, 'complete', :, :].drop(columns = ['pyr_acc', 'in_acc'])
plot_results(complete, 'complete')
# Out:
# Loading data set from ./data_sets/complete/spatial/0_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 306 waveforms (59.766%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 246 waveforms (80.392%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 60 waveforms (19.608%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 102 waveforms (19.922%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 82 waveforms (80.392%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 20 waveforms (19.608%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 104 waveforms (20.312%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 83 waveforms (79.808%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 21 waveforms (20.192%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)

# %%
complete = results.loc[:, 'complete', :, :].drop(columns = ['pyr_acc', 'in_acc'])
plot_results(complete, 'complete', acc=False)
# Out:
# Loading data set from ./data_sets/complete/spatial/0_0.60.20.2/...
# Total number of clusters in train data is 306 (59.766%) consisting of 306 waveforms (59.766%)
# Total number of pyramidal clusters in train data is 246 (80.392%) consisting of 246 waveforms (80.392%)
# Total number of interneurons clusters in train data is 60 (19.608%) consisting of 60 waveforms (19.608%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 102 (19.922%) consisting of 102 waveforms (19.922%)
# Total number of pyramidal clusters in dev data is 82 (80.392%) consisting of 82 waveforms (80.392%)
# Total number of interneurons clusters in dev data is 20 (19.608%) consisting of 20 waveforms (19.608%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 104 (20.312%) consisting of 104 waveforms (20.312%)
# Total number of pyramidal clusters in test data is 83 (79.808%) consisting of 83 waveforms (79.808%)
# Total number of interneurons clusters in test data is 21 (20.192%) consisting of 21 waveforms (20.192%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)

# %%
no_small_sample = results.loc[:, 'no_small_sample', :, :].drop(columns = ['pyr_acc', 'in_acc'])
plot_results(no_small_sample, 'no_small_sample')
# Out:
# Loading data set from ./data_sets/no_small_sample/spatial/0_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 202 waveforms (59.587%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 148 waveforms (73.267%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 54 waveforms (26.733%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 68 waveforms (20.059%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 50 waveforms (73.529%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 18 waveforms (26.471%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 69 waveforms (20.354%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 50 waveforms (72.464%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 19 waveforms (27.536%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)

# %%
no_small_sample = results.loc[:, 'no_small_sample', :, :].drop(columns = ['pyr_acc', 'in_acc'])
plot_results(no_small_sample, 'no_small_sample', acc=False)
# Out:
# Loading data set from ./data_sets/no_small_sample/spatial/0_0.60.20.2/...
# Total number of clusters in train data is 202 (59.587%) consisting of 202 waveforms (59.587%)
# Total number of pyramidal clusters in train data is 148 (73.267%) consisting of 148 waveforms (73.267%)
# Total number of interneurons clusters in train data is 54 (26.733%) consisting of 54 waveforms (26.733%)
# Total number of untagged clusters in train data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in dev data is 68 (20.059%) consisting of 68 waveforms (20.059%)
# Total number of pyramidal clusters in dev data is 50 (73.529%) consisting of 50 waveforms (73.529%)
# Total number of interneurons clusters in dev data is 18 (26.471%) consisting of 18 waveforms (26.471%)
# Total number of untagged clusters in dev data is 0 (0.000%) consisting of 0 waveforms (0.000%)
# Total number of clusters in test data is 69 (20.354%) consisting of 69 waveforms (20.354%)
# Total number of pyramidal clusters in test data is 50 (72.464%) consisting of 50 waveforms (72.464%)
# Total number of interneurons clusters in test data is 19 (27.536%) consisting of 19 waveforms (27.536%)
# Total number of untagged clusters in test data is 0 (0.000%) consisting of 0 waveforms (0.000%)
